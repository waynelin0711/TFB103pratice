# %%
target = 'dog'
A_list = ['cat', 'dog', 'dog', 'pig', 'dog']
while(target in list):
    list.remove(target)
list
# Out:
# ['cat', 'pig']

# %%
A ='Afghanistan'
seg_list= ['BRUSSELS', ' ', '—', ' ', 'Afghanistan', '’', 's', ' ', 'rapid', ' ', 'unraveling', ' ', 'is', ' ', 'already', ' ', 'raising', ' ', 'grumblings', ' ', 'about', ' ', 'American', ' ', 'credibility', ',', ' ', 'compounding', ' ', 'the', ' ', 'wounds', ' ', 'of', ' ', 'the', ' ', 'Trump', ' ', 'years', ' ', 'and', ' ', 'reinforcing', ' ', 'the', ' ', 'idea', ' ', 'that', ' ', 'America', '’', 's', ' ', 'backing', ' ', 'for', ' ', 'its', ' ', 'allies', ' ', 'is', ' ', 'not', ' ', 'unlimited', '.', '\n', '\n', 'The', ' ', 'Taliban', '’', 's', ' ', 'lightning', ' ', 'advance', ' ', 'comes', ' ', 'at', ' ', 'a', ' ', 'moment', ' ', 'when', ' ', 'many', ' ', 'in', ' ', 'Europe', ' ', 'and', ' ', 'Asia', ' ', 'had', ' ', 'hoped', ' ', 'that', ' ', 'President', ' ', 'Biden', ' ', 'would', ' ', 'reestablish', ' ', 'America', '’', 's', ' ', 'firm', ' ', 'presence', ' ', 'in', ' ', 'international', ' ', 'affairs', ',', ' ', 'especially', ' ', 'as', ' ', 'China', ' ', 'and', ' ', 'Russia', ' ', 'angle', ' ', 'to', ' ', 'extend', ' ', 'their', ' ', 'influence', '.', ' ', 'Now', ',', ' ', 'America', '’', 's', ' ', 'retreat', ' ', 'is', ' ', 'bound', ' ', 'to', ' ', 'sow', ' ', 'doubts', '.', '\n', '\n', '“', 'When', ' ', 'Biden', ' ', 'says', ' ', '‘', 'America', ' ', 'is', ' ', 'back', ',', '’', ' ', 'many', ' ', 'people', ' ', 'will', ' ', 'say', ',', ' ', '‘', 'Yes', ',', ' ', 'America', ' ', 'is', ' ', 'back', ' ', 'home', ',', '’', '”', ' ', 'said', ' ', 'Fran', 'ç', 'ois', ' ', 'Heisbourg', ',', ' ', 'a', ' ', 'French', ' ', 'defense', ' ', 'analyst', '.', '\n', '\n', '“', 'Few', ' ', 'will', ' ', 'gang', ' ', 'up', ' ', 'on', ' ', 'the', ' ', 'U', '.', 'S', '.', ' ', 'for', ' ', 'finally', ' ', 'stopping', ' ', 'a', ' ', 'failed', ' ', 'enterprise', ',', '”', ' ', 'he', ' ', 'said', '.', ' ', '“', 'Most', ' ', 'people', ' ', 'would', ' ', 'say', ' ', 'it', ' ', 'should', ' ', 'have', ' ', 'happened', ' ', 'a', ' ', 'long', ' ', 'time', ' ', 'ago', '.', '’', '’', ' ', 'But', ' ', 'in', ' ', 'the', ' ', 'longer', ' ', 'term', ',', ' ', 'he', ' ', 'added', ',', ' ', '“', 'the', ' ', 'notion', ' ', 'that', ' ', 'you', ' ', 'cannot', ' ', 'count', ' ', 'on', ' ', 'the', ' ', 'Americans', ' ', 'will', ' ', 'strike', ' ', 'deeper', ' ', 'roots', ' ', 'because', ' ', 'of', ' ', 'Afghanistan', '.']
while(A in seg_list):
    seg_list.remove(A)
seg_list
# Out:
# ['BRUSSELS',
#  ' ',
#  '—',
#  ' ',
#  '’',
#  's',
#  ' ',
#  'rapid',
#  ' ',
#  'unraveling',
#  ' ',
#  'is',
#  ' ',
#  'already',
#  ' ',
#  'raising',
#  ' ',
#  'grumblings',
#  ' ',
#  'about',
#  ' ',
#  'American',
#  ' ',
#  'credibility',
#  ',',
#  ' ',
#  'compounding',
#  ' ',
#  'the',
#  ' ',
#  'wounds',
#  ' ',
#  'of',
#  ' ',
#  'the',
#  ' ',
#  'Trump',
#  ' ',
#  'years',
#  ' ',
#  'and',
#  ' ',
#  'reinforcing',
#  ' ',
#  'the',
#  ' ',
#  'idea',
#  ' ',
#  'that',
#  ' ',
#  'America',
#  '’',
#  's',
#  ' ',
#  'backing',
#  ' ',
#  'for',
#  ' ',
#  'its',
#  ' ',
#  'allies',
#  ' ',
#  'is',
#  ' ',
#  'not',
#  ' ',
#  'unlimited',
#  '.',
#  '\n',
#  '\n',
#  'The',
#  ' ',
#  'Taliban',
#  '’',
#  's',
#  ' ',
#  'lightning',
#  ' ',
#  'advance',
#  ' ',
#  'comes',
#  ' ',
#  'at',
#  ' ',
#  'a',
#  ' ',
#  'moment',
#  ' ',
#  'when',
#  ' ',
#  'many',
#  ' ',
#  'in',
#  ' ',
#  'Europe',
#  ' ',
#  'and',
#  ' ',
#  'Asia',
#  ' ',
# ...

# %%
AF_count=len([X for X in A_list if X=="Afghanistan" ])
AF_count
# Out:
# 2

# %%
AF_count
# Out:
# ['Afghanistan', 'Afghanistan']

# %%
sum = 0
i = 0
while i <= 10:
    sum = sum + i
    i = i +1
print("Sum of first five even numbers =", sum)
# Out:
# Sum of first five even numbers = 55

# %%
from functools import reduce
for i in range(1, 6):
    A=reduce(lamdba x,y:i*(i+1), i)

print(A)
# Out:
#   File "<ipython-input-69-cdff407b65cc>", line 3
#     A=reduce(lamdba x,y:i*(i+1), i)
#                     ^
# SyntaxError: invalid syntax

# %%
from functools import reduce
def multiply(x, y): 
    return x * y 
reduce(multiply, [1, 2, 3, 4, 5])
# Out:
# 120

# %%
n = 6
A=reduce(lambda x, y: x * y, range(1, n))
A
# Out:
# 120
